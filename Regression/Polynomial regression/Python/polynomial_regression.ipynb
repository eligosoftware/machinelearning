# %% [markdown]
# **Importing the libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Importing dataset**

# %%
drive_path='/content/drive/My Drive/ml_course/Part 2 - Regression/Section 6 - Polynomial Regression/Python/'
dataset=pd.read_csv(drive_path+'Position_Salaries.csv')
x=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1:].values

# %% [markdown]
# **Training the Linear Regression Model**

# %%
from sklearn.linear_model import LinearRegression

linear_regressor=LinearRegression()
linear_regressor.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# **Training the Polynomial Regression Model**

# %%
from sklearn.preprocessing import PolynomialFeatures
pol_feat=PolynomialFeatures(degree=4)
x_poly=pol_feat.fit_transform(x)

lin_reg2=LinearRegression()
lin_reg2.fit(x_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# **Visualising the linear regression results**

# %%
plt.scatter(x,y,color='red')
plt.plot(x,linear_regressor.predict(x),color='blue')
plt.title('Truth or Bluff (Linear regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# **Visualising the Polynomial regression results**

# %%
plt.scatter(x,y,color='red')
plt.plot(x,lin_reg2.predict(x_poly),color='blue')
plt.title('Truth or Bluff (Polynomial regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# **Visualising the Polynomial regression results (for smoother curve)**

# %%
x_grid=np.arange(min(x),max(x),0.1)
x_grid=x_grid.reshape(len(x_grid),1)
plt.scatter(x,y,color='red')
plt.plot(x_grid,lin_reg2.predict(pol_feat.fit_transform(x_grid)),color='blue')
plt.title('Truth or Bluff (Polynomial regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# **Predicting salary**

# %%
lin_sal=linear_regressor.predict([[6.5]]) #linear regression
lin_sal
# Out:
# array([[330378.78787879]])

# %%
lin_reg2.predict(pol_feat.fit_transform([[6.5]])) #polynomial regression
# Out:
# array([[158862.45265155]])
