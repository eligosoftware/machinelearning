# %% [markdown]
# **Decision Tree Regression**

# %% [markdown]
# **Importing the libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Importing dataset**

# %%
drive_path='/content/drive/My Drive/ml_course/Part 2 - Regression/Section 8 - Decision Tree Regression/Python/'
dataset=pd.read_csv(drive_path+'Position_Salaries.csv')
x=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1:].values

# %% [markdown]
# **Training the Decision Tree Regression Model on the whole dataset**

# %%
from sklearn.tree import DecisionTreeRegressor
regr_1=DecisionTreeRegressor(random_state=0)
regr_1.fit(x,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %% [markdown]
# **Predicting a new result**

# %%
y_pred=regr_1.predict([[6.5]])
print(y_pred)
# Out:
# [150000.]

# %% [markdown]
# **Visualising the Decision Tree Regression results (higher resolution)**

# %%
# Plot the results
x_grid=np.arange(min(x),max(x),0.1)
x_grid=x_grid.reshape(len(x_grid),1)
plt.figure()
plt.scatter(x, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(x_grid, regr_1.predict(x_grid), color="cornflowerblue",
         label="max_depth=2", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
# Plot the results
plt.figure()
plt.scatter(x, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(x, regr_1.predict(x), color="cornflowerblue",
         label="max_depth=2", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
